# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
#Import CSV
file = 'clean.csv'

# %%
#Convert to Dataframe
df = pd.read_csv(file)
df
# Out:
#                     Id  OwnerCity OwnerState      PropertyLocationStreet1  \
# 0    12009f31026acc440  PINEHURST         NC             5833 NEWBURY CIR
# 1    120112bfc77a87376   STAFFORD         VA               12723 SW 49 CT
# 2    12081776a04b281f4   RICHMOND         VA     6470 SEAGULL DR UNIT 307
# 3    12103fabafeea9fb7  ARLINGTON         VA  1012 NORTH SHORE DR NE # 12
# 4    120213b0f5f17e3d1  ROCK HILL         SC          5550 HERON POINT DR
# ..                 ...        ...        ...                          ...
# 223  12086e1ddd12521cd   BLUFFTON         SC                5765 NW 99 CT
# 224  120861813f1294d56   RICHMOND         VA             7805 NOREMAC AVE
# 225  12089ed366ee68b8e  MARS HILL         NC           246 S FLETCHER AVE
# 226  1211544028709F1DD     OAKTON         VA   171 VISTA HERMOSA CIR 21-B
# 227  1212772a5d810d464   MATTHEWS         NC                3 SUNSET BLVD
#
#          PropertyCity  PropertyZip       StateParcelId  ParcelSize  \
# 0           MELBOURNE        32940  C15-000-035-4368-3     10890.0
# 1             MIRAMAR        33027  C16-000-107-5040-4      2328.0
# 2           BRADENTON        34210  C51-000-535-8660-8        44.0
# 3    SAINT PETERSBURG        33701  C62-000-778-7949-2         NaN
# 4              NAPLES        34108  C21-000-189-4508-9         NaN
# ..                ...          ...                 ...         ...
# 223             DORAL        33178  C23-000-278-7237-3      3473.0
# 224       MIAMI BEACH        33141  C23-000-207-1780-7      9000.0
# 225  FERNANDINA BEACH        32034  C55-000-585-3872-9      6650.0
# 226          SARASOTA        34242  C68-000-867-0448-3         NaN
# 227      ORMOND BEACH        32176  C74-000-925-7435-9      8800.0
#
#      ValueofHome  YearBuilt  ... FireID  DistancetoFireDepartment  \
# 0       360350.0     2001.0  ...    NaN                      1.67
# 1       228680.0     2003.0  ...  645.0                      2.37
# 2       135000.0     1980.0  ...    NaN                      0.96
# 3        87660.0     1959.0  ...  855.0                      1.08
# 4       663090.0     1991.0  ...   50.0                      1.37
# ..           ...        ...  ...    ...                       ...
# 223     329160.0     1993.0  ...    NaN                      0.27
# 224     924061.0     1941.0  ...  627.0                      0.71
# 225     274291.0     1929.0  ...  359.0                      1.23
# 226     267400.0     1971.0  ...    NaN                      1.13
# 227     172189.0     1967.0  ...    NaN                      0.59
#
#      DistancetoSinkhole SinkholeLatitude SinkholeLongitude  LocationWindSpeed  \
# 0                 19.32         28.46383         -80.79177              120.0
# 1                  5.11         25.98582         -80.23586              140.0
# 2                  1.93         27.41706         -82.56742              130.0
# 3                  1.00         27.77333         -82.64000              123.0
# 4                 11.43         26.27444         -81.63916              131.0
# ..                  ...              ...               ...                ...
# 223               13.46         25.98582         -80.23586              146.0
# 224                7.25         25.96256         -80.16641              146.0
# 225                6.33         30.67020         -81.53824              120.0
# 226                2.29         27.27514         -82.55399              130.0
# 227                0.97         29.35629         -81.07076              120.0
#
#      WindborneDebrisRegion  Terrain            FloodZone  FloodZoneRiskLevel
# 0                     True     B                   X:100                 NaN
# 1                     True     HVHZ                X:100                 NaN
# 2                     True     C                   A:100                 NaN
# 3                     True     C     X500:40, A:30, X:30                 NaN
# 4                     True     C                   A:100                 NaN
# ..                     ...      ...                  ...                 ...
# 223                   True     HVHZ                X:100                 NaN
# 224                   True     HVHZ                A:100                 NaN
# 225                   True     C                   X:100                 NaN
# 226                   True     B                   A:100                 NaN
# 227                   True     C                   X:100                 NaN
#
# [228 rows x 29 columns]

# %%
#Filter the appropriate columns
new_df = df[['Id','OwnerState','StateParcelId','ParcelSize','ValueofHome',
             'YearBuilt','TypeOfResidence','NumberOfStories','AdjSquareFeet',]]
new_df
# Out:
#                     Id OwnerState       StateParcelId  ParcelSize  \
# 0    12009f31026acc440         NC  C15-000-035-4368-3     10890.0
# 1    120112bfc77a87376         VA  C16-000-107-5040-4      2328.0
# 2    12081776a04b281f4         VA  C51-000-535-8660-8        44.0
# 3    12103fabafeea9fb7         VA  C62-000-778-7949-2         NaN
# 4    120213b0f5f17e3d1         SC  C21-000-189-4508-9         NaN
# ..                 ...        ...                 ...         ...
# 223  12086e1ddd12521cd         SC  C23-000-278-7237-3      3473.0
# 224  120861813f1294d56         VA  C23-000-207-1780-7      9000.0
# 225  12089ed366ee68b8e         NC  C55-000-585-3872-9      6650.0
# 226  1211544028709F1DD         VA  C68-000-867-0448-3         NaN
# 227  1212772a5d810d464         NC  C74-000-925-7435-9      8800.0
#
#      ValueofHome  YearBuilt       TypeOfResidence  NumberOfStories  \
# 0       360350.0     2001.0         SINGLE FAMILY              2.0
# 1       228680.0     2003.0  ATTACHED RESIDENTIAL              NaN
# 2       135000.0     1980.0         CONDO STACKED              NaN
# 3        87660.0     1959.0         CONDO STACKED              1.0
# 4       663090.0     1991.0         CONDO STACKED              NaN
# ..           ...        ...                   ...              ...
# 223     329160.0     1993.0         SINGLE FAMILY              NaN
# 224     924061.0     1941.0         SINGLE FAMILY              NaN
# 225     274291.0     1929.0         SINGLE FAMILY              NaN
# 226     267400.0     1971.0             CONDO ROW              NaN
# 227     172189.0     1967.0         SINGLE FAMILY              1.0
#
#      AdjSquareFeet
# 0           3716.0
# 1           1633.0
# 2           1254.0
# 3            445.0
# 4           1263.0
# ..             ...
# 223         1957.0
# 224         3056.0
# 225          783.0
# 226         1114.0
# 227         1188.0
#
# [228 rows x 9 columns]

# %%
#MakeSureNoNullValues

new_df['ValueofHome'].unique()
# Out:
# array([ 360350.,  228680.,  135000.,   87660.,  663090.,  298880.,
#         141668.,  161169.,  302070.,  122040.,  177505.,  277190.,
#          62414.,  202770.,  259580.,  152459.,   88850.,   77100.,
#         218245.,  363580.,  206570.,  155519.,   53098.,  746751.,
#         371402.,  354430.,  299587.,   51000.,   90660.,  311180.,
#         585440.,  162000.,   99174.,  219010.,  125900.,  279900.,
#         166345.,   92000.,  202800.,   47530.,  184821.,   68260.,
#          84700.,  798030.,   29700.,  141290.,   78353.,  182170.,
#         270230.,  101568.,  342380.,  216104.,  130441.,  271407.,
#         263500.,  310459.,  152573.,  161550.,  167130.,  128160.,
#         320650.,  370083.,  156660.,  138127.,  133900.,   82850.,
#         219652.,  262320.,  301060.,   68328.,   66690.,  294724.,
#          42779.,  117354.,  164566.,  195489.,  167948.,  396226.,
#         241436.,   58910.,  140513.,   73500.,   75000.,  231832.,
#          57900.,  173283.,  326520.,  226750.,  136104.,  264660.,
#         104100.,  294000.,  375402.,  516500.,  155848.,   75481.,
#         213472.,  102769.,  144250.,   97500.,  126100.,  462780.,
#         346418.,  260988.,  366340.,   63664.,   41180.,  459615.,
#         111555.,   79234.,  323815.,  164129.,  270980.,   81867.,
#         447700.,  187647.,  156400.,   49370.,  222009.,  199911.,
#         224489.,   69267.,  140100.,  265392.,  124118.,  196160.,
#         101184.,  105312.,  268577.,  152586.,  187753.,   68840.,
#          93128.,  285420.,   33448.,  234052.,   96591.,  303478.,
#         860090.,  151358.,   80370.,  142750.,  401300.,  308881.,
#         459202.,  176200.,  276928.,  477221.,  590120.,  148026.,
#         237107.,  738202.,  682216.,  388278.,  656181.,  134144.,
#         356110.,  665535.,  195135.,  108500.,  134108.,  226522.,
#         407912.,  539397.,  201627.,  198652.,  596890.,  191588.,
#         781237.,  246940.,  150160.,  208723.,   93865.,  438018.,
#         340597.,  842684.,  333488.,  173892.,  190680.,  411702.,
#         582782.,  535400.,  433500.,  368800.,  305050.,  140958.,
#         231300.,  178754.,   31320.,  104640.,   99757.,   74851.,
#         194195.,   93120.,  120239.,  461408.,  398899.,  340300.,
#         519425.,  267447., 1233088.,  898356.,  254659.,  169146.,
#         239336.,  367387.,  136375.,  200000.,   79135.,  159735.,
#         652363.,   82384.,  168430.,   48140.,  618435.,  129071.,
#          36961.,  228401.,   64998.,   91800.,  151500.,  203651.,
#         150040.,  329160.,  924061.,  274291.,  267400.,  172189.])

# %%
#Find Correlation between columns
new_df.corr()
# Out:
#                  ParcelSize  ValueofHome  YearBuilt  NumberOfStories  \
# ParcelSize         1.000000     0.052753  -0.123119        -0.058345
# ValueofHome        0.052753     1.000000   0.149435         0.199246
# YearBuilt         -0.123119     0.149435   1.000000         0.396607
# NumberOfStories   -0.058345     0.199246   0.396607         1.000000
# AdjSquareFeet      0.179059     0.560435   0.192882         0.248371
#
#                  AdjSquareFeet
# ParcelSize            0.179059
# ValueofHome           0.560435
# YearBuilt             0.192882
# NumberOfStories       0.248371
# AdjSquareFeet         1.000000

# %%
#Get specific correlation coefficient betweeen AdjSqFt and Value of Home
r_asf = new_df['ValueofHome'].corr(new_df['AdjSquareFeet'])
r2_asf = round(r_asf * r_asf,2)

print(f'Correlation (R^2) of Home Value versus Square Footage is {r2_asf}')

x_values = new_df['AdjSquareFeet']
y_values = new_df['ValueofHome']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f'Linear Regresssion equation is.....{line_eq}')

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color= 'r')
plt.title('Square Footage vs Home Value')
plt.xlabel('Square Footage')
plt.ylabel('Home Value ($ Millions of Dollars)')
plt.annotate(line_eq,(4000,400000),color = 'r')
plt.annotate(f'R-Squared= {r2_asf}', (4000,325000), color = 'r')
print(f'The Correlation between Square Footage and Home Value is weak when considering the entire state of Florida')

#Save the figure as PNG
plt.savefig('SquareFootageScatter.png')
# Out:
# Correlation (R^2) of Home Value versus Square Footage is 0.31
# Linear Regresssion equation is.....y = 109.74x + 41644.81
# The Correlation between Square Footage and Home Value is weak when considering the entire state of Florida

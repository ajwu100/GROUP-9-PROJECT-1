# %%
import pandas as pd

# %%
file = 'House_price_multifeatures.csv'

# %%
df = pd.read_csv(file)
# Out:
# /Users/tah96/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_short = df.head(10)

# %%
df_short
# Out:
#                   Id       PropertyLocationStreet1 PropertyLocationStreet2  \
# 0  120210f35317ca697           503 LAKE LOUISE CIR                  19-201
# 0  12086db272d757be6                  5934 NW 7 PL                     NaN
# 0  12057c35a22b0865c            5713 PALM RIVER RD                     NaN
# 0  12057cf31f8e69893       1805 MAGDALENE MANOR DR                     NaN
# 0  12057c5b7712cfb0b          7405 ALAFIA RIDGE LP                     NaN
# 0  12057a9d507819528              1715 CINNABAR CT                     NaN
# 0  12057fc3fb8804556              802 FOX HILLS DR                     NaN
# 0  1205784c858ba39d6                1836 CRAVEN DR                     NaN
# 0  120571eb9b1f70b2c  13759 JUNIPER BLOSSOM DR 101                     NaN
# 0  12057e4b4e43b1b20             3907 WEST LAKE DR                     NaN
#
#       PropertyCity  CountyFIPS  PropertyZip                       OwnerName  \
# 0           NAPLES        21.0        34110       BOLTZ, LARRY P & SANDRA A
# 0            MIAMI        86.0        33127              LILIANE MORISSETTE
# 0            TAMPA        57.0        33619                   PADRON LUIS A
# 0            TAMPA        57.0        33613                 BELLO CELESTE M
# 0        RIVERVIEW        57.0        33569                     LANE ROY JR
# 0          BRANDON        57.0        33510                 ALBRIGHT SANDRA
# 0  SUN CITY CENTER        57.0        33573  RODRIGUEZ GLORIA H LIFE ESTATE
# 0          SEFFNER        57.0        33584             AVIRETT CATHERINE A
# 0            TAMPA        57.0        33618                   COOPER JOHN D
# 0          SEFFNER        57.0        33584                  TAH HOLDING LP
#
#          OwnerMailAddress1 OwnerMailAddress2        OwnerCity  ...  \
# 0     3739 WRENS NEST BLVD               NaN           MAUMEE  ...
# 0             5934 NW 7 PL               NaN            MIAMI  ...
# 0       5713 PALM RIVER RD               NaN            TAMPA  ...
# 0  1805 MAGDALENE MANOR DR               NaN            TAMPA  ...
# 0   7405 ALAFIA RIDGE LOOP               NaN        RIVERVIEW  ...
# 0         1715 CINNABAR CT               NaN          BRANDON  ...
# 0         802 FOX HILLS DR               NaN  SUN CITY CENTER  ...
# 0           1836 CRAVEN DR               NaN          SEFFNER  ...
# 0  1628 HARRINGTON PARK DR               NaN     JACKSONVILLE  ...
# 0             PO BOX 15087               NaN        SANTA ANA  ...
#
#   HydrantLatitude HydrantLongitude  LastSalePrice LastSaleDate  Homestead  \
# 0             NaN              NaN            NaN          NaN      False
# 0        25.83045        -80.21022            NaN          NaN       True
# 0        27.94326        -82.39026            NaN          NaN       True
# 0        28.07439        -82.47757            NaN          NaN       True
# 0        27.87574        -82.29307            NaN          NaN       True
# 0        27.97226        -82.30971            NaN          NaN       True
# 0        27.72448        -82.34824            NaN          NaN       True
# 0        27.97836        -82.27822            NaN          NaN       True
# 0        28.07865        -82.48839        78000.0       Mar-18      False
# 0        27.98138        -82.29623            NaN          NaN      False
#
#    FloodzoneLastUpdatedDate       StateParcelId  AssesmentYear Geometry  \
# 0              5/12/17 0:00  C21-000-188-9852-8         2015.0      NaN
# 0              12/8/17 0:00  C23-000-198-3578-4         2015.0      NaN
# 0               1/1/31 0:00  C39-000-406-3313-3         2015.0      NaN
# 0               4/4/18 0:00  C39-000-389-2623-4         2015.0      NaN
# 0               1/1/31 0:00  C39-000-414-6909-9         2015.0      NaN
# 0               4/4/18 0:00  C39-000-411-1518-9         2015.0      NaN
# 0              5/20/18 0:00  C39-000-416-1560-0         2015.0      NaN
# 0               4/4/18 0:00  C39-000-411-4081-5         2015.0      NaN
# 0              2/23/15 0:00  C39-000-955-1597-9         2015.0      NaN
# 0               4/4/18 0:00  C39-000-411-2244-1         2015.0      NaN
#
#   TTTerritory
# 0       541-0
# 0       032-0
# 0       080-0
# 0       080-0
# 0       080-0
# 0       080-0
# 0       080-0
# 0       080-0
# 0       080-0
# 0       080-0
#
# [10 rows x 95 columns]

# %%
new_df = df[['Id','OwnerCity', 'OwnerState','PropertyLocationStreet1','PropertyCity','PropertyZip','StateParcelId','ParcelSize','ValueofHome','YearBuilt','TypeOfResidence','NumberOfStories','AdjSquareFeet',
            'Pool','PPC', 'BCEG', 'DistancetoCoast', 'PoliceID','Crime','FireID','DistancetoFireDepartment', 'DistancetoSinkhole','SinkholeLatitude',
            'SinkholeLongitude', 'LocationWindSpeed', 'WindborneDebrisRegion', 'Terrain', 'FloodZone', 'FloodZoneRiskLevel']]
new_df
# Out:
#                    Id     OwnerCity OwnerState  PropertyLocationStreet1  \
# 0   120210f35317ca697        MAUMEE         OH      503 LAKE LOUISE CIR
# 0   12086db272d757be6         MIAMI         FL             5934 NW 7 PL
# 0   12057c35a22b0865c         TAMPA         FL       5713 PALM RIVER RD
# 0   12057cf31f8e69893         TAMPA         FL  1805 MAGDALENE MANOR DR
# 0   12057c5b7712cfb0b     RIVERVIEW         FL     7405 ALAFIA RIDGE LP
# ..                ...           ...        ...                      ...
# 0   120865661a78fa3c8         MIAMI         FL           9221 NW 17 AVE
# 0   1200980de660f371c     MELBOURNE         FL          1199 HOUSTON ST
# 0   1208698914968668a  CORAL GABLES         FL          3715 HARLANO ST
# 0   120117d9876b67325     HOLLYWOOD    FLORIDA             714 N 32 AVE
# 0   1208671d49043ce45         MIAMI         FL            6520 SW 42 ST
#
#     PropertyCity  PropertyZip       StateParcelId  ParcelSize  ValueofHome  \
# 0         NAPLES        34110  C21-000-188-9852-8         NaN     200840.0
# 0          MIAMI        33127  C23-000-198-3578-4      4880.0     164994.0
# 0          TAMPA        33619  C39-000-406-3313-3     16913.0     200346.0
# 0          TAMPA        33613  C39-000-389-2623-4     27374.0     364161.0
# 0      RIVERVIEW        33569  C39-000-414-6909-9     43883.0     138691.0
# ..           ...          ...                 ...         ...          ...
# 0          MIAMI        33147  C23-000-240-0005-1      8250.0     114432.0
# 0      MELBOURNE        32935  C15-001-090-5145-8     10890.0     119690.0
# 0   CORAL GABLES        33134  C23-000-211-7828-0      7875.0     539553.0
# 0      HOLLYWOOD        33021  C16-000-116-3292-4      6502.0     194190.0
# 0          MIAMI        33155  C23-000-246-8734-5      8906.0     336184.0
#
#     YearBuilt  ... FireID  DistancetoFireDepartment  DistancetoSinkhole  \
# 0      1988.0  ...   50.0                      1.20                 NaN
# 0      2004.0  ...  626.0                      0.98                9.56
# 0      2005.0  ...    NaN                      0.05                0.82
# 0      1984.0  ...    NaN                      1.69                0.39
# 0      1986.0  ...    NaN                      1.37                1.09
# ..        ...  ...    ...                       ...                 ...
# 0      1949.0  ...    NaN                      0.57                8.07
# 0      1956.0  ...  620.0                      0.52               25.42
# 0      1939.0  ...    NaN                      0.66               16.74
# 0      1956.0  ...  459.0                      0.49                1.97
# 0      1954.0  ...    NaN                      1.62               18.05
#
#    SinkholeLatitude SinkholeLongitude  LocationWindSpeed  \
# 0               NaN               NaN              129.0
# 0          25.96256         -80.16641              146.0
# 0          27.94389         -82.37694              120.0
# 0          28.08028         -82.47806              120.0
# 0          27.89053         -82.29201              120.0
# ..              ...               ...                ...
# 0          25.96256         -80.16641              146.0
# 0          28.46383         -80.79177              120.0
# 0          25.96256         -80.16641              146.0
# 0          25.99000         -80.18329              140.0
# 0          25.96256         -80.16641              146.0
#
#     WindborneDebrisRegion  Terrain      FloodZone  FloodZoneRiskLevel
# 0                    True     B             A:100                 NaN
# 0                    True     HVHZ          A:100                 NaN
# 0                    True     B             A:100                 NaN
# 0                    True     B        A:60, X:40                 NaN
# 0                    True     B     X:80, X500:20                 NaN
# ..                    ...      ...            ...                 ...
# 0                    True     HVHZ          X:100                 NaN
# 0                    True     C             X:100                 NaN
# 0                    True     HVHZ          X:100                 NaN
# 0                    True     HVHZ       X500:100                 NaN
# 0                    True     HVHZ          A:100                 NaN
#
# [59213 rows x 29 columns]

# %%
new_df['OwnerState'].unique()
# Out:
# array(['OH', 'FL', 'CA', 'FLORIDA', 'GA', 'NJ', 'OHIO', 'AZ', 'MN',
#        'TEXAS', 'TX', 'NY', 'FRANCE', 'CANADA', ' FL', 'MA', 'CALIFORNIA',
#        'NC', 'MI', 'IL', 'MO', 'NEW YORK', 'NEW JERSEY', 'VIRGINIA',
#        'GEORGIA', 'MD', 'MICHIGAN', 'VENEZUELA', 'PA', 'AL', 'VA',
#        'UNITED KINGDOM', 'SC', 'WI', 'TN', 'CT', nan, 'IN', 'QC', ' CA',
#        'KY', 'KENTUCKY', 'ARIZONA', 'CONNECTICUT', 'MARYLAND',
#        'NEW HAMPSHIRE', 'PR', 'PENNSLYVANIA', 'ISRAEL', 'RI', 'CO',
#        'COLORADO', 'NORTH CAROLINA', 'LA', 'OK', 'DC', 'ID', 'KS',
#        'DELAWARE', 'ME', 'PARAGUAY', 'OREGON', 'ILLINOIS', 'PENNSYLVANIA',
#        'VI', 'GUATEMALA', 'GREAT BRITAIN', 'DISTRICT OF COLUMBIA',
#        'MINNESOTA', 'MEXICO', 'MASSACHUSETTS', 'NH', 'GERMANY',
#        'SINGAPORE', 'INDIANA', 'DE', 'UTAH', 'RHODE ISLAND', 'ALASKA',
#        'NEVADA', 'TENNESSEE', 'ITALY', 'NE', 'GBR', 'HI', 'ON', 'NORWAY',
#        'IA', 'WV', 'UT', 'SPAIN', 'VIRGIN ISLANDS', 'PUERTO RICO', 'UK',
#        'OKLAHOMA', 'WISCONSIN', 'BELGIUM', 'PHILIPPINES', 'IRELAND',
#        'LOUISIANA', 'PERU', 'ALABAMA', 'NORTHERN IRELAND', 'NB', 'AK',
#        'VERMONT', 'BRAZIL', 'OR', 'VT', 'AR', 'MAINE', 'NEW MEXICO',
#        'ICELAND', 'CHE', 'NETHERLANDS', 'GREAT BRITAIN & NRTHRN IR',
#        'SWEDEN', 'HUNGARY', 'SCOTLAND', 'SD', 'UNITED ARAB EMIRATES',
#        'AE', 'MT', 'ENGLAND', 'UNITED STATES OF AMERICA', ' NJ', 'WA',
#        'TRINIDAD AND TOBAGO', 'WY', 'MISSOURI', 'MS', 'CAN', 'KANSAS',
#        'SWITZERLAND', 'SOUTH CAROLINA', 'GUAM', 'FK', 'AP', 'NV',
#        'ENGLAND U K', 'GREECE', 'WASHINGTON', 'IOWA', 'ARGENTINA',
#        'PORTUGAL', 'ND', 'HAWAII', 'FINLAND', 'COLOMBIA', 'NM', 'AB',
#        'TRINIDAD & TOBAGO', 'BOGOTA-COLOMBIA', 'BERMUDA', 'PANAMA',
#        'NEBRASKA', 'BC', 'SOUTH DAKOTA', 'ARKANSAS', 'MILITARY AP'],
#       dtype=object)

# %%
new_df['OwnerState'] = new_df['OwnerState'].replace(
    {'NORTH CAROLINA': 'NC', 'VIRGINIA': 'VA', 'SOUTH CAROLINA': 'SC'})
# Out:
# /Users/tah96/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df['OwnerState'].unique()
# Out:
# array(['OH', 'FL', 'CA', 'FLORIDA', 'GA', 'NJ', 'OHIO', 'AZ', 'MN',
#        'TEXAS', 'TX', 'NY', 'FRANCE', 'CANADA', ' FL', 'MA', 'CALIFORNIA',
#        'NC', 'MI', 'IL', 'MO', 'NEW YORK', 'NEW JERSEY', 'VA', 'GEORGIA',
#        'MD', 'MICHIGAN', 'VENEZUELA', 'PA', 'AL', 'UNITED KINGDOM', 'SC',
#        'WI', 'TN', 'CT', nan, 'IN', 'QC', ' CA', 'KY', 'KENTUCKY',
#        'ARIZONA', 'CONNECTICUT', 'MARYLAND', 'NEW HAMPSHIRE', 'PR',
#        'PENNSLYVANIA', 'ISRAEL', 'RI', 'CO', 'COLORADO', 'LA', 'OK', 'DC',
#        'ID', 'KS', 'DELAWARE', 'ME', 'PARAGUAY', 'OREGON', 'ILLINOIS',
#        'PENNSYLVANIA', 'VI', 'GUATEMALA', 'GREAT BRITAIN',
#        'DISTRICT OF COLUMBIA', 'MINNESOTA', 'MEXICO', 'MASSACHUSETTS',
#        'NH', 'GERMANY', 'SINGAPORE', 'INDIANA', 'DE', 'UTAH',
#        'RHODE ISLAND', 'ALASKA', 'NEVADA', 'TENNESSEE', 'ITALY', 'NE',
#        'GBR', 'HI', 'ON', 'NORWAY', 'IA', 'WV', 'UT', 'SPAIN',
#        'VIRGIN ISLANDS', 'PUERTO RICO', 'UK', 'OKLAHOMA', 'WISCONSIN',
#        'BELGIUM', 'PHILIPPINES', 'IRELAND', 'LOUISIANA', 'PERU',
#        'ALABAMA', 'NORTHERN IRELAND', 'NB', 'AK', 'VERMONT', 'BRAZIL',
#        'OR', 'VT', 'AR', 'MAINE', 'NEW MEXICO', 'ICELAND', 'CHE',
#        'NETHERLANDS', 'GREAT BRITAIN & NRTHRN IR', 'SWEDEN', 'HUNGARY',
#        'SCOTLAND', 'SD', 'UNITED ARAB EMIRATES', 'AE', 'MT', 'ENGLAND',
#        'UNITED STATES OF AMERICA', ' NJ', 'WA', 'TRINIDAD AND TOBAGO',
#        'WY', 'MISSOURI', 'MS', 'CAN', 'KANSAS', 'SWITZERLAND', 'GUAM',
#        'FK', 'AP', 'NV', 'ENGLAND U K', 'GREECE', 'WASHINGTON', 'IOWA',
#        'ARGENTINA', 'PORTUGAL', 'ND', 'HAWAII', 'FINLAND', 'COLOMBIA',
#        'NM', 'AB', 'TRINIDAD & TOBAGO', 'BOGOTA-COLOMBIA', 'BERMUDA',
#        'PANAMA', 'NEBRASKA', 'BC', 'SOUTH DAKOTA', 'ARKANSAS',
#        'MILITARY AP'], dtype=object)

# %%
clean_df = new_df.loc[(new_df['OwnerState'] == 'NC') | (new_df['OwnerState'] == 'SC') | (new_df['OwnerState'] == 'VA')]
clean_df
# Out:
#                    Id  OwnerCity OwnerState      PropertyLocationStreet1  \
# 0   12009f31026acc440  PINEHURST         NC             5833 NEWBURY CIR
# 0   120112bfc77a87376   STAFFORD         VA               12723 SW 49 CT
# 0   12081776a04b281f4   RICHMOND         VA     6470 SEAGULL DR UNIT 307
# 0   12103fabafeea9fb7  ARLINGTON         VA  1012 NORTH SHORE DR NE # 12
# 0   120213b0f5f17e3d1  ROCK HILL         SC          5550 HERON POINT DR
# ..                ...        ...        ...                          ...
# 0   12086e1ddd12521cd   BLUFFTON         SC                5765 NW 99 CT
# 0   120861813f1294d56   RICHMOND         VA             7805 NOREMAC AVE
# 0   12089ed366ee68b8e  MARS HILL         NC           246 S FLETCHER AVE
# 0   1211544028709F1DD     OAKTON         VA   171 VISTA HERMOSA CIR 21-B
# 0   1212772a5d810d464   MATTHEWS         NC                3 SUNSET BLVD
#
#         PropertyCity  PropertyZip       StateParcelId  ParcelSize  \
# 0          MELBOURNE        32940  C15-000-035-4368-3     10890.0
# 0            MIRAMAR        33027  C16-000-107-5040-4      2328.0
# 0          BRADENTON        34210  C51-000-535-8660-8        44.0
# 0   SAINT PETERSBURG        33701  C62-000-778-7949-2         NaN
# 0             NAPLES        34108  C21-000-189-4508-9         NaN
# ..               ...          ...                 ...         ...
# 0              DORAL        33178  C23-000-278-7237-3      3473.0
# 0        MIAMI BEACH        33141  C23-000-207-1780-7      9000.0
# 0   FERNANDINA BEACH        32034  C55-000-585-3872-9      6650.0
# 0           SARASOTA        34242  C68-000-867-0448-3         NaN
# 0       ORMOND BEACH        32176  C74-000-925-7435-9      8800.0
#
#     ValueofHome  YearBuilt  ... FireID  DistancetoFireDepartment  \
# 0      360350.0     2001.0  ...    NaN                      1.67
# 0      228680.0     2003.0  ...  645.0                      2.37
# 0      135000.0     1980.0  ...    NaN                      0.96
# 0       87660.0     1959.0  ...  855.0                      1.08
# 0      663090.0     1991.0  ...   50.0                      1.37
# ..          ...        ...  ...    ...                       ...
# 0      329160.0     1993.0  ...    NaN                      0.27
# 0      924061.0     1941.0  ...  627.0                      0.71
# 0      274291.0     1929.0  ...  359.0                      1.23
# 0      267400.0     1971.0  ...    NaN                      1.13
# 0      172189.0     1967.0  ...    NaN                      0.59
#
#     DistancetoSinkhole SinkholeLatitude SinkholeLongitude  LocationWindSpeed  \
# 0                19.32         28.46383         -80.79177              120.0
# 0                 5.11         25.98582         -80.23586              140.0
# 0                 1.93         27.41706         -82.56742              130.0
# 0                 1.00         27.77333         -82.64000              123.0
# 0                11.43         26.27444         -81.63916              131.0
# ..                 ...              ...               ...                ...
# 0                13.46         25.98582         -80.23586              146.0
# 0                 7.25         25.96256         -80.16641              146.0
# 0                 6.33         30.67020         -81.53824              120.0
# 0                 2.29         27.27514         -82.55399              130.0
# 0                 0.97         29.35629         -81.07076              120.0
#
#     WindborneDebrisRegion  Terrain            FloodZone  FloodZoneRiskLevel
# 0                    True     B                   X:100                 NaN
# 0                    True     HVHZ                X:100                 NaN
# 0                    True     C                   A:100                 NaN
# 0                    True     C     X500:40, A:30, X:30                 NaN
# 0                    True     C                   A:100                 NaN
# ..                    ...      ...                  ...                 ...
# 0                    True     HVHZ                X:100                 NaN
# 0                    True     HVHZ                A:100                 NaN
# 0                    True     C                   X:100                 NaN
# 0                    True     B                   A:100                 NaN
# 0                    True     C                   X:100                 NaN
#
# [228 rows x 29 columns]

# %%
clean_df.to_csv('clean.csv', index = False, header = True)
